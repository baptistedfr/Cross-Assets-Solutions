# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# !pip install pandas numpy matplotlib yfinance PyPortfolioOpt
import os
if not os.path.isdir('data'):
    os.system('git clone https://github.com/robertmartin8/PyPortfolioOpt.git')
    os.chdir('PyPortfolioOpt/cookbook')
# Out:
# Requirement already satisfied: pandas in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (2.0.0)
# Requirement already satisfied: matplotlib in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (3.10.0)
# Requirement already satisfied: yfinance in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (0.2.51)
# Requirement already satisfied: PyPortfolioOpt in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (1.5.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: requests>=2.31 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: cvxpy>=1.1.19 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from PyPortfolioOpt) (1.6.4)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from PyPortfolioOpt) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from PyPortfolioOpt) (5.24.1)
# Requirement already satisfied: scipy>=1.3 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from PyPortfolioOpt) (1.14.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: osqp>=0.6.2 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (0.6.7.post3)
# Requirement already satisfied: clarabel>=0.5.0 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (3.2.7.post2)
# Requirement already satisfied: six>=1.9 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (8.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31->yfinance) (2024.6.2)
# Requirement already satisfied: qdldl in c:\users\thibc\appdata\local\programs\python\python312\lib\site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (0.1.7.post5)

# %%
df = pd.read_excel(r"C:\Users\thibc\OneDrive\Documents\Dev\Cross-Assets-Solutions\datas\Stoxx600_sectors_prices_cleen.xlsx").set_index("Date")
df.head()
# Out:
#             Technology  Telecommunications  Health Care  Financials  \
# Date
# 2011-05-09  100.000000          100.000000   100.000000  100.000000
# 2011-05-10  101.489142          100.071333   100.004909  101.279328
# 2011-05-11  101.636641          101.060745   101.067694  101.564491
# 2011-05-12  101.139950          100.175350   101.735310  100.800823
# 2011-05-13  100.711645           99.292570   102.317903   99.769005
#
#             Real Estate  Consumer Discretionary  Consumer Staples  \
# Date
# 2011-05-09   100.000000              100.000000        100.000000
# 2011-05-10   100.988875              101.137178        100.439376
# 2011-05-11   101.165460              102.068410        101.224642
# 2011-05-12   100.688681              101.477436        101.439656
# 2011-05-13   100.476779              101.289398        101.570534
#
#             Industrials  Basic Materials      Energy   Utilities
# Date
# 2011-05-09   100.000000       100.000000  100.000000  100.000000
# 2011-05-10   101.182716       101.431208  100.735358  101.038121
# 2011-05-11   101.473118       100.297198  100.446468  101.958113
# 2011-05-12   100.548226        98.737624   98.756894  101.156045
# 2011-05-13   100.276834        98.262015   98.100324  100.475121

# %%
from pypfopt import risk_models
from pypfopt import plotting

sample_cov = risk_models.sample_cov(df, frequency=252)
plotting.plot_covariance(sample_cov, plot_correlation=True)
# Out:
# <Axes: >

# %%
from pypfopt import expected_returns

mu = expected_returns.mean_historical_return(df, frequency=252)
mu.plot.barh(figsize=(10,6))
# Out:
# <Axes: >

# %%
from pypfopt import EfficientFrontier

ef = EfficientFrontier(mu, sample_cov)

ef.add_constraint(lambda x: x <= 0.15)

ef.efficient_risk(target_volatility=0.15)
# ef.max_sharpe()
weights = ef.clean_weights()

# Filtrer les secteurs avec un poids > 0
filtered_sector_allocation = {k: v for k, v in weights.items() if v > 0}

secteurs = list(filtered_sector_allocation.keys())
poids = list(filtered_sector_allocation.values())

# Création du graphique de répartition sectorielle
fig, ax = plt.subplots(figsize=(10,10))
ax.pie(poids, labels=secteurs, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Assure que le graphique est circulaire
plt.title('Allocation Stratégique')
plt.show()
weights
# Out:
# OrderedDict([('Technology', 0.15),
#              ('Telecommunications', 0.14972),
#              ('Health Care', 0.15),
#              ('Financials', 0.0),
#              ('Real Estate', 0.0),
#              ('Consumer Discretionary', 0.10028),
#              ('Consumer Staples', 0.15),
#              ('Industrials', 0.15),
#              ('Basic Materials', 0.0),
#              ('Energy', 0.0),
#              ('Utilities', 0.15)])

# %% [markdown]
# Test Black Litterman

# %%
from pypfopt import black_litterman, risk_models
from pypfopt import BlackLittermanModel, plotting

market_prior = pd.Series(weights)

viewdict = {
    "Technology": 0.25,
    "Telecommunications": 0.30,
    "Health Care": 0.05,
    "Financials": 0.0,
    "Real Estate": 0.20,
    "Consumer Discretionary": -0.05,
    "Consumer Staples": 0.15,
    "Industrials": 0.10,
    "Basic Materials": 0.20,
    "Energy": 0.0,
    "Utilities": 0.20
}
views = pd.Series(viewdict)
views = views[market_prior > 0]
views = views / views.sum()

bl = BlackLittermanModel(sample_cov, pi=market_prior, absolute_views=views)
ret_bl = bl.bl_returns()
print("Returns")
print(ret_bl)
print("-----")
print("BL weights")
w_bl = pd.Series(bl.bl_weights())
print(w_bl)
print("-----")
print("Prior weights")
print(market_prior)
# Out:
# Technology                0.149163
# Telecommunications        0.186218
# Health Care               0.124122
# Financials               -0.002404
# Real Estate              -0.002701
# Consumer Discretionary    0.075329
# Consumer Staples          0.144682
# Industrials               0.132577
# Basic Materials          -0.012474
# Energy                    0.001972
# Utilities                 0.169574
# dtype: float64
# -----
# Technology                0.298199
# Telecommunications        1.318409
# Health Care              -0.308856
# Financials               -1.321447
# Real Estate              -0.909375
# Consumer Discretionary   -0.698349
# Consumer Staples          0.791468
# Industrials               2.591584
# Basic Materials          -1.273254
# Energy                   -0.135177
# Utilities                 0.646799
# dtype: float64

# %%
ret_bl = ret_bl / ret_bl.sum()
rets_df = pd.DataFrame([market_prior, ret_bl, pd.Series(views)],
             index=["Prior", "Posterior", "Views"]).T
rets_df["Posterior"] = rets_df["Posterior"] / rets_df["Posterior"].sum()

# %%
rets_df.plot.bar(figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# ------------------------

# %%
print("Perf portefeuille optimisé :")
ef.portfolio_performance(verbose=True);
# Out:
# Perf portefeuille optimisé :
# Expected annual return: 7.5%
# Annual volatility: 15.0%
# Sharpe Ratio: 0.50

# %%
import yfinance as yf

stoxx600 = yf.Ticker("^STOXX")
data = stoxx600.history(period="5y", interval="1d")
data["returns"] = data["Close"].pct_change()


mean_daily_return = data["returns"].mean()
annual_return = (1 + mean_daily_return) ** 252 - 1
annual_volatility = data["returns"].std() * np.sqrt(252)
sharpe_ratio = annual_return / annual_volatility

print(f"Perf STOXX600 :\nExpected annual return: {annual_return:.2%}\nAnnual volatility: {annual_volatility:.2%}\nSharpe Ratio: {sharpe_ratio:.2f}")
# Out:
# Perf STOXX600 :
# Expected annual return: 7.74%
# Annual volatility: 17.55%
# Sharpe Ratio: 0.44

# %%
# Données de répartition sectorielle
secteurs = ["Consommation courante", "Consommation non essentielle", "Énergie", "Immobilier", "Industries", "Matériaux de base", "Santé", "Services aux collectivités", "Sociétés financières", "Technologie", "Télécommunications", "Unknown"]
poids = [0.077088013, 0.125418618, 0.052218956, 0.013057364, 0.179035648, 0.043628194, 0.146921617, 0.035596528, 0.212169866, 0.081237039, 0.027647824, 0.005980304]

# Création du graphique
fig, ax = plt.subplots(figsize=(10,10))
ax.pie(poids, labels=secteurs, autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Assure que le graphique est circulaire

# Titre du graphique
plt.title('Répartition sectorielle du STOXX Europe 600')

# Affichage du graphique
plt.show()
